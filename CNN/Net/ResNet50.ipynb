# %%
from tensorflow.keras.applications import (
    ResNet50,
    InceptionV3,
    VGG16,
    VGG19,
    MobileNet,
    DenseNet201,
    NASNetLarge,
    NASNetMobile
)
from tensorflow.keras.preprocessing import image
from tensorflow.keras.applications.resnet50 import preprocess_input, decode_predictions
import numpy as np

# %%
model=ResNet50(weights="imagenet")

# %%
img_path="/content/Cat-Photography-682451ed80d7d__700.webp"
img=image.load_img(img_path, target_size=(224, 224))
x= image.img_to_array(img)
x=np.expand_dims(x, axis=0)
x=preprocess_input(x)

# %%
x
# Out:
# array([[[[ -88.939   , -101.779   , -108.68    ],
#          [ -87.939   , -100.779   , -107.68    ],
#          [ -87.939   , -100.779   , -107.68    ],
#          ...,
#          [ -52.939003,  -65.779   ,  -72.68    ],
#          [ -52.939003,  -65.779   ,  -72.68    ],
#          [ -52.939003,  -65.779   ,  -72.68    ]],
#
#         [[ -87.939   , -100.779   , -107.68    ],
#          [ -87.939   , -100.779   , -107.68    ],
#          [ -86.939   ,  -99.779   , -106.68    ],
#          ...,
#          [ -52.939003,  -65.779   ,  -72.68    ],
#          [ -52.939003,  -65.779   ,  -72.68    ],
#          [ -52.939003,  -65.779   ,  -72.68    ]],
#
#         [[ -87.939   , -100.779   , -107.68    ],
#          [ -86.939   ,  -99.779   , -106.68    ],
#          [ -86.939   ,  -99.779   , -106.68    ],
#          ...,
#          [ -52.939003,  -65.779   ,  -72.68    ],
#          [ -51.939003,  -64.779   ,  -71.68    ],
#          [ -51.939003,  -64.779   ,  -71.68    ]],
#
#         ...,
#
#         [[ -97.939   , -110.779   , -117.68    ],
#          [ -93.939   , -106.779   , -113.68    ],
#          [ -94.939   , -107.779   , -114.68    ],
#          ...,
#          [ -28.939003,  -41.779   ,  -48.68    ],
#          [ -30.939003,  -43.779   ,  -50.68    ],
#          [ -30.939003,  -43.779   ,  -50.68    ]],
#
#         [[ -97.939   , -110.779   , -117.68    ],
#          [ -94.939   , -107.779   , -114.68    ],
#          [ -95.939   , -108.779   , -115.68    ],
#          ...,
#          [ -28.939003,  -41.779   ,  -48.68    ],
#          [ -30.939003,  -43.779   ,  -50.68    ],
#          [ -30.939003,  -43.779   ,  -50.68    ]],
#
#         [[ -97.939   , -110.779   , -117.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          [ -96.939   , -109.779   , -116.68    ],
#          ...,
#          [ -30.939003,  -43.779   ,  -50.68    ],
#          [ -30.939003,  -43.779   ,  -50.68    ],
#          [ -31.939003,  -44.779   ,  -51.68    ]]]], dtype=float32)

# %%
preds=model.predict(x)
print("predicted", decode_predictions(preds, top=3)[0])
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 3s 3s/step
# predicted [('n02124075', 'Egyptian_cat', np.float32(0.8036598)), ('n02123045', 'tabby', np.float32(0.13980731)), ('n02123159', 'tiger_cat', np.float32(0.024146967))]
